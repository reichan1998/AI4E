# %% [markdown]
# 1. Cartoonify Image with Machine Learning
#
# Input: The real image of an object
#
# Output: The cartoonified image of a given object
#
# Type: Unsupervised learning - dimension reduction

# %% [markdown]
# 2. Iris Flowers Classification Project
# - Input: The lenght of petals and sepals of an iris flower.
# - Output: The species name of given iris flower
# - Type: Supervised learning - classification

# %% [markdown]
# 3. Emojify – Create your own emoji with Python
# - Input: human facial expression, human-based emojis
# - Output:
# 1. a convolution neural network to recognize facial emotions.
# 2. an emoji which is corresponded to this emotion
# - Type: Supervised learning - classification

# %% [markdown]
# 4. Loan Prediction using Machine Learning
# - Input: the user’s marital status, education, number of dependents, and employments.
# - Output: how much loan the user can take.
# - Type: Supervised learning - Regression

# %% [markdown]
# 5. Housing Prices Prediction Project
# - Input: Factors like crime rate, number of rooms
# - Output: House's price
# - Type: supervised learning - regression

# %% [markdown]
# 6. MNIST Digit Classification Machine Learning Project
# - Input: an image of handwritten digits
# - Output: name of handwritten digits
# - Type: supervised learning- classification

# %% [markdown]
# 7. Stock Price Prediction using Machine Learning
# - Input: the previous year's data stock market prices
# - Output: the future price of the stock market
# - Type: supervised learning - regression

# %% [markdown]
# 8. Titanic Survival Project
# - Input:
# data of passenger data  (ie name, age, gender, socio-economic class, etc).
# data of the survivors and people who died in the Titanic ship
# - output: a predictive model returning that a passenger will survive or die
# - type: supervised learning - classification

# %% [markdown]
# 9. Wine Quality Test Project
# - Input: the chemical information of wine
# - Output: return the normal/excellent/poor wine
# - type: supervised - classification

# %% [markdown]
# 10. Fake News Detection Project
# - Input:  a peice of news
# - Output: return Fake or Real
# - Type: supervised- classification

# %% [markdown]
# 11. Music Genre Classification Machine Learning Project
# - Input1: audio files of 10 music genres
# - output1: low-level features of frequency and time domain of audio of 10 music genres
# - output 2: a predictive model based on feature extraction
# - type: supervised learning - classification

# %% [markdown]
# 12. Bitcoin Price Predictor Project
# - input: previous data of price of the bicoin
# - output: the future price
# - type: supervised - regression

# %% [markdown]
# 13. Uber Data Analysis Project
# - input: 4.5 millions of uber pickups in the new york city.
# - output: a map
# - types: not machine learning

# %% [markdown]
# 14. Personality Prediction Project
# - input1: the type of posts a person put on social media
# - input2: The Myers Briggs Type Indicator.
# - output: the personality of a person
# - type: supervised-classification

# %% [markdown]
# 15. Handwritten Character Recognition
# - input1: images of handwritten characters, i.e, English alphabets from A-Z.
# - output1: the predictive model (convolutional neutral networks model)
# - input 2: the image of any handwritten character
# - output2: the name of given handwritten character
# - type: supervised - classification

# %% [markdown]
# 16. Xbox Game Prediction Project
# - input: search queries (features, colors, models, ...)
# - output: a product that a user will be most interested to buy.
# - type: supervised - classification

# %% [markdown]
# 17. Credit Card Fraud Detection Project
# - input1: the characteristics of fraud and non-fraud transaction
# - output1: a predictive model to predict fraud score
# - input2: a data from a predictive model
# - output2: an improved model
# - types: unsupervised and supervised learning

# %% [markdown]
# 18. Sign Language Recognition with Machine Learning
# - input1: images of hand gestures describing the alphabets and numbers from 1 to 10
# - output1: a CNN model
# - input2: a series of hand gestures
# - output2: a message
# - type: supervised - classification

# %% [markdown]
# 19. Barbie with Brains Project
# - input1: some pairs of common sentences/question children usually speaking and corresponding sentences/answers
# - output1: a predictive model
# - type: supervised-classification

# %% [markdown]
# 20. Customer Segmentation using Machine Learning
# - input: customers' purchase history, gender, age, interest, etc.
#
# - output: insight of different customer groups
# - type: unsupervising-clustering

# %% [markdown]
# 21. Sentiment Analysis using Machine Learning
# - input:
